# %% [markdown]
# # Import important libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import os

# %% [markdown]
# # Define important configurations

# %%
train_path = "/kaggle/input/archive/train"
test_path = "/kaggle/input/archive/test"

IMG_HEIGHT = 48
IMG_WIDTH = 48

BATCH_SIZE = 64 # for model.fit()
EPOCHS = 40

LR = 0.0002
NUM_CLASSES = 7
PATIENCE = 4 # For Early stopping

# CLASS_LABELS  = ['Surprise', 'Fear', 'Anger', 'Neutral', 'Sadness', 'Disgust', 'Happy']
CLASS_LABELS  = ['Anger', 'Disgust', 'Fear', 'Happy', 'Neutral', 'Sadness', "Surprise"]

# %% [markdown]
# # Data Input and Data Augumentation

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import to_categorical


train_datagen = ImageDataGenerator(horizontal_flip=True,
                                   rescale = 1./255,
                                   validation_split = 0.2,
                                   rotation_range = 10
                                  )

train_generator = train_datagen.flow_from_directory(
                        directory = train_path,
                        target_size = (IMG_HEIGHT ,IMG_WIDTH),
                        batch_size = BATCH_SIZE,
                        shuffle  = True , 
                        class_mode = "categorical",
                        subset = "training",
                        seed = 12
                       )

validation_generator = train_datagen.flow_from_directory(
                        directory = train_path,
                        target_size = (IMG_HEIGHT ,IMG_WIDTH),
                        batch_size = BATCH_SIZE,
                        shuffle  = True , 
                        class_mode = "categorical",
                        subset = "validation",
                        seed = 12
                    )
# Out:
# Found 22968 images belonging to 7 classes.
# Found 5741 images belonging to 7 classes.

# %% [markdown]
# # Display some preprocessing statistics

# %% [markdown]
# **Classes counting**

# %%
ctg = os.listdir(train_path)
counts = []
for e in ctg:
    counts.append(len(os.listdir(train_path + f'/{e}')))
    
counts
# Out:
# [3171, 4097, 3995, 4965, 4830, 436, 7215]

# %%
df_hist = pd.DataFrame()
df_hist['category'] = CLASS_LABELS 
df_hist['count'] = counts
df_hist
# Out:
#    category  count
# 0     Anger   3171
# 1   Disgust   4097
# 2      Fear   3995
# 3     Happy   4965
# 4   Neutral   4830
# 5   Sadness    436
# 6  Surprise   7215

# %% [markdown]
# **Classes counting visualization**

# %%
px.bar(df_hist, x='category', y='count')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.32.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="5644ddf3-23ec-4121-9920-c53e11972ccc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5644ddf3-23ec-4121-9920-c53e11972ccc")) {                    Plotly.newPlot(                        "5644ddf3-23ec-4121-9920-c53e11972ccc",                        [{"alignmentgroup":"True","hovertemplate":"category=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Anger","Disgust","Fear","Happy","Neutral","Sadness","Surprise"],"xaxis":"x","y":[3171,4097,3995,4965,4830,436,7215],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outline ...

# %% [markdown]
# # Get traninng features (images) and corresponding labels

# %%
imgs, labels = next(validation_generator)  
validation_generator.reset()
len(imgs)
# Out:
# 64

# %% [markdown]
# # Let's take a brief look at images data

# %%
img = imgs[0]
print(img.shape)

plt.figure(figsize=(15,15))

for i in range(16):
    plt.subplot(4,4,i+1)
    plt.imshow(imgs[i])
    plt.title(CLASS_LABELS[np.argmax(labels[i])])
plt.show()
# Out:
# (48, 48, 3)

# %% [markdown]
# # Building model

# %%
from keras.layers import Conv2D, MaxPooling2D, MaxPool2D, Flatten,Dense,Dropout,Activation,BatchNormalization,GlobalAveragePooling2D
from keras.models import Model,Sequential
from keras import regularizers
from tensorflow.keras.optimizers import Adam,SGD,RMSprop

# %%
Simple_CNN_model = Sequential()

Simple_CNN_model.add(Conv2D(64, (3,3), activation="relu", padding="same", kernel_initializer='he_uniform', name='block1_conv1', 
                 input_shape=(IMG_HEIGHT, IMG_WIDTH, 3) ))
Simple_CNN_model.add(Conv2D(64, (3,3), activation="relu", padding="same", kernel_initializer='he_uniform', name='block1_conv2'))
Simple_CNN_model.add(MaxPool2D(pool_size=(2,2), strides=(2,2), name='block1_maxpool'))

Simple_CNN_model.add(Conv2D(128, (3,3), activation="relu", padding="same", kernel_initializer='he_uniform', name='block2_conv1'))
Simple_CNN_model.add(Conv2D(128, (3,3), activation="relu", padding="same", kernel_initializer='he_uniform', name='block2_conv2'))
Simple_CNN_model.add(MaxPool2D(pool_size=(2,2), strides=(2,2), name='block2_maxpool'))
Simple_CNN_model.add(Dropout(0.25))

Simple_CNN_model.add(Conv2D(256, (3,3), activation="relu", padding="same", kernel_initializer='he_uniform', name='block3_conv1'))
Simple_CNN_model.add(Conv2D(256, (3,3), activation="relu", padding="same", kernel_initializer='he_uniform', name='block3_conv2'))
Simple_CNN_model.add(MaxPool2D(pool_size=(2,2), strides=(2,2), name='block3_maxpool'))

Simple_CNN_model.add(Conv2D(512, (3,3), activation="relu", padding="same", kernel_initializer='he_uniform', name='block4_conv1'))
Simple_CNN_model.add(Conv2D(512, (3,3), activation="relu", padding="same", kernel_initializer='he_uniform', name='block4_conv2'))
Simple_CNN_model.add(Conv2D(512, (3,3), activation="relu", padding="same", kernel_initializer='he_uniform', name='block4_conv3'))
Simple_CNN_model.add(MaxPool2D(pool_size=(2,2), strides=(2,2), name='block4_maxpool'))
Simple_CNN_model.add(Dropout(0.25))


Simple_CNN_model.add(Flatten())
Simple_CNN_model.add(Dense(4096, activation='relu'))
Simple_CNN_model.add(Dense(4096, activation='relu'))
Simple_CNN_model.add(Dense(NUM_CLASSES, activation='softmax'))

Simple_CNN_model.summary()
# Out:
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ block1_conv1 (Conv2D)           │ (None, 48, 48, 64)     │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 48, 48, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_maxpool (MaxPooling2D)   │ (None, 24, 24, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, 24, 24, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv2 (Conv2D)           │ (None, 24, 24, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_maxpool (MaxPooling2D)   │ (None, 12, 12, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 12, 12, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv1 (Conv2D)           │ (None, 12, 12, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv2 (Conv2D)           │ (None, 12, 12, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_maxpool (MaxPooling2D)   │ (None, 6, 6, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv1 (Conv2D)           │ (None, 6, 6, 512)      │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv2 (Conv2D)           │ (None, 6, 6, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv3 (Conv2D)           │ (None, 6, 6, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_maxpool (MaxPooling2D)   │ (None, 3, 3, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 3, 3, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 4608)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 4096)           │    18,878,464 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 4096)           │    16,781,312 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 7)              │        28,679 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 42,733,639 (163.02 MB)
#  Trainable params: 42,733,639 (163.02 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# # Enhance model techniques

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping


Simple_CNN_model.compile(
    optimizer = Adam(learning_rate = LR), 
    loss='categorical_crossentropy', 
    metrics=['accuracy']
  )

checkpoint = ModelCheckpoint("checkpoint_weights.keras", monitor='val_acc', verbose=1, save_best_only=True, mode='max')

early_stopping = EarlyStopping(monitor='val_loss',
                          patience= PATIENCE,
                          verbose=1,
                          restore_best_weights=True
                          )

CALLBACKS = [early_stopping, checkpoint]

# %% [markdown]
# # Model training

# %%
history = Simple_CNN_model.fit(x = train_generator,
                    epochs = EPOCHS ,
                    validation_data = validation_generator , 
                    callbacks = CALLBACKS 
                   )
# Out:
# Epoch 1/40
# /opt/conda/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning:
#
# Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1734269372.877625     109 service.cc:145] XLA service 0x79c634006510 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1734269372.877679     109 service.cc:153]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1734269372.877683     109 service.cc:153]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
#   2/359 ━━━━━━━━━━━━━━━━━━━━ 26s 74ms/step - accuracy: 0.1758 - loss: 3.6419
# I0000 00:00:1734269383.161180     109 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 221s 554ms/step - accuracy: 0.2474 - loss: 2.1291 - val_accuracy: 0.3738 - val_loss: 1.5879
# Epoch 2/40
# /opt/conda/lib/python3.10/site-packages/keras/src/callbacks/model_checkpoint.py:206: UserWarning:
#
# Can save best model only with val_acc available, skipping.
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 53s 145ms/step - accuracy: 0.3867 - loss: 1.5746 - val_accuracy: 0.4219 - val_loss: 1.4821
# Epoch 3/40
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 46s 127ms/step - accuracy: 0.4436 - loss: 1.4462 - val_accuracy: 0.4694 - val_loss: 1.3984
# Epoch 4/40
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 48s 131ms/step - accuracy: 0.4762 - loss: 1.3515 - val_accuracy: 0.4891 - val_loss: 1.3261
# Epoch 5/40
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 47s 130ms/step - accuracy: 0.5058 - loss: 1.2819 - val_accuracy: 0.5299 - val_loss: 1.2409
# Epoch 6/40
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 46s 127ms/step - accuracy: 0.5386 - loss: 1.1951 - val_accuracy: 0.5375 - val_loss: 1.2090
# Epoch 7/40
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 46s 126ms/step - accuracy: 0.5583 - loss: 1.1547 - val_accuracy: 0.5466 - val_loss: 1.1652
# Epoch 8/40
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 47s 128ms/step - accuracy: 0.5796 - loss: 1.1108 - val_accuracy: 0.5647 - val_loss: 1.1369
# Epoch 9/40
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 46s 127ms/step - accuracy: 0.5887 - loss: 1.0756 - val_accuracy: 0.5595 - val_loss: 1.1607
# Epoch 10/40
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 47s 129ms/step - accuracy: 0.6082 - loss: 1.0322 - val_accuracy: 0.5738 - val_loss: 1.1092
# Epoch 11/40
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 46s 126ms/step - accuracy: 0.6172 - loss: 1.0035 - val_accuracy: 0.5799 - val_loss: 1.1003
# Epoch 12/40
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 47s 129ms/step - accuracy: 0.6374 - loss: 0.9575 - val_accuracy: 0.5894 - val_loss: 1.0865
# Epoch 13/40
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 47s 127ms/step - accuracy: 0.6562 - loss: 0.9243 - val_accuracy: 0.5881 - val_loss: 1.0898
# Epoch 14/40
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 48s 132ms/step - accuracy: 0.6630 - loss: 0.8924 - val_accuracy: 0.5989 - val_loss: 1.1184
# Epoch 15/40
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 53s 146ms/step - accuracy: 0.6833 - loss: 0.8431 - val_accuracy: 0.6025 - val_loss: 1.0798
# Epoch 16/40
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 47s 128ms/step - accuracy: 0.6942 - loss: 0.8173 - val_accuracy: 0.6049 - val_loss: 1.0702
# Epoch 17/40
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 50s 138ms/step - accuracy: 0.7112 - loss: 0.7709 - val_accuracy: 0.6056 - val_loss: 1.0940
# Epoch 18/40
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 50s 138ms/step - accuracy: 0.7243 - loss: 0.7397 - val_accuracy: 0.5945 - val_loss: 1.1249
# Epoch 19/40
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 49s 135ms/step - accuracy: 0.7414 - loss: 0.7017 - val_accuracy: 0.5950 - val_loss: 1.1357
# Epoch 20/40
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 48s 131ms/step - accuracy: 0.7496 - loss: 0.6733 - val_accuracy: 0.6063 - val_loss: 1.1653
# Epoch 20: early stopping
# Restoring model weights from the end of the best epoch: 16.

# %% [markdown]
# # Saving model

# %%
Simple_CNN_model.save('./model/simple_CNN_model.h5')

# %% [markdown]
# # Evaluation

# %% [markdown]
# **Loss and Accuracy of Training Process**

# %%
def plot_analysis(m):
  plt.figure(figsize=(10,5))

  plt.subplot(1,2,1)

  plt.plot(m.history['loss'],color="#E74C3C")
  plt.plot(m.history['val_loss'],color='#641E16')

  plt.title('Validation loss vs Train loss',fontsize=8)
  plt.ylabel('Loss')
  plt.xlabel('Epoch')
  plt.legend(['Train', 'validation'], loc='upper right')

  plt.subplot(1,2,2)

  plt.plot(m.history['accuracy'],color="#E74C3C")
  plt.plot(m.history['val_accuracy'],color='#641E16')

  plt.title('Validation accuracy vs Train accuracy',fontsize=8)
  plt.ylabel('Accuracy')
  plt.xlabel('Epoch')
  plt.legend(['Train', 'validation'], loc='lower right')

  plt.show()

# %%
plot_analysis(history)

# %% [markdown]
# # Evaluate on test set

# %% [markdown]
# **Get test data**

# %%
test_datagen = ImageDataGenerator(
                                rescale = 1./255,
                                    )

test_generator = test_datagen.flow_from_directory(
                        directory = test_path,
                        target_size = (IMG_HEIGHT ,IMG_WIDTH),
                        batch_size = BATCH_SIZE,
                        class_mode = "categorical",
                        shuffle = False,
                      )
# Out:
# Found 7178 images belonging to 7 classes.

# %% [markdown]
# **Evalute on test set**

# %%
#Evalute on test set
e = Simple_CNN_model.evaluate(x=test_generator, verbose=1)
# Out:
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 30s 270ms/step - accuracy: 0.5710 - loss: 1.1466

# %% [markdown]
# **Classification Report**

# %%
test_generator.reset()
p = Simple_CNN_model.predict(test_generator)
# Out:
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 7s 62ms/step

# %%
test_generator.reset()
labels_test = [CLASS_LABELS[item] for item in test_generator.labels]
labels_pred = [CLASS_LABELS[np.argmax(item)] for item in p]

from sklearn.metrics import *
print(classification_report(labels_test, labels_pred))
# Out:
#               precision    recall  f1-score   support
#
#        Anger       0.56      0.53      0.54       958
#      Disgust       0.56      0.40      0.46       111
#         Fear       0.46      0.39      0.42      1024
#        Happy       0.83      0.83      0.83      1774
#      Neutral       0.54      0.61      0.57      1233
#      Sadness       0.46      0.54      0.50      1247
#     Surprise       0.79      0.68      0.73       831
#
#     accuracy                           0.61      7178
#    macro avg       0.60      0.57      0.58      7178
# weighted avg       0.62      0.61      0.61      7178

# %% [markdown]
# **Confusion matrix**

# %%
cfm = confusion_matrix(labels_test, labels_pred)

import plotly.figure_factory as ff

# Set up figure 
fig = ff.create_annotated_heatmap(np.flipud(cfm)
, x = CLASS_LABELS, y = list(np.flip(CLASS_LABELS)), colorscale='Purples')

# Add titles
fig.update_layout(title_text='<i><b>Confusion matrix</b></i>',
                  xaxis = dict(title='Predicted label'),
                  yaxis = dict(title='True label'))

# Adjust margins (top, left), width and height
fig.update_layout(margin=dict(t=100, l=100), width = 750, height = 750)

# Add colorbar
fig['data'][0]['showscale'] = True

fig.show()
# Out:
# <div>                            <div id="b4340636-4986-4865-bd87-f4fdbd55d3d1" class="plotly-graph-div" style="height:750px; width:750px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b4340636-4986-4865-bd87-f4fdbd55d3d1")) {                    Plotly.newPlot(                        "b4340636-4986-4865-bd87-f4fdbd55d3d1",                        [{"colorscale":[[0.0,"rgb(252,251,253)"],[0.125,"rgb(239,237,245)"],[0.25,"rgb(218,218,235)"],[0.375,"rgb(188,189,220)"],[0.5,"rgb(158,154,200)"],[0.625,"rgb(128,125,186)"],[0.75,"rgb(106,81,163)"],[0.875,"rgb(84,39,143)"],[1.0,"rgb(63,0,125)"]],"reversescale":false,"showscale":true,"x":["Anger","Disgust","Fear","Happy","Neutral","Sadness","Surprise"],"y":["Surprise","Sadness","Neutral","Happy","Fear","Disgust","Anger"],"z":[[28,3,131,52,27,24,566],[113,5,118,77,246,673,15],[66,2,66,85,751,249,14],[50,0,44,1471,132,54,23],[107,6,396,35,124,278,78],[34,44,10,5,4,13,1],[504,19,94,39,111,171,20]],"type":"heatmap"}],                        {"annotations":[{"font":{"color":"#000000"},"showarrow":false,"text":"28","x":"Anger","xref":"x","y":"Surprise","yref":"y"},{"font":{"color":"#000000"},"showarrow":false,"text":"3","x":"Disgust","xref":"x","y":"Surprise","yref":"y"},{"font":{"color":"#000000"},"showarrow":false,"text":"131","x":"Fear","xref":"x","y":"Surprise","yref":"y"},{"font":{"color":"#000000"},"showarrow":false,"text":"52","x":"Happy","xref":"x","y":"Surprise","yref":"y"},{"font":{"color":"#000000"},"showarrow":false,"text":"27","x":"Neutral","xref":"x","y":"Surprise","yref":"y"},{"font":{"color":"#000000"},"showarrow":false,"text":"24","x":"Sadness","xref":"x","y":"Surprise","yref":"y"},{"font":{"color":"#000000"},"showarrow":false,"text":"566","x":"Surprise","xref":"x","y":"Surprise","yref":"y"},{"font":{"color":"#000000"},"showarrow":false,"text":"113","x":"Anger","xref":"x","y":"Sadness","yref":"y"},{"font":{"color":"#000000"},"showarrow":false,"text":"5","x":"Disgust","xref":"x","y":"Sadness","yref":"y"},{"font":{"color":"#000000"},"showarrow":false,"text":"118","x":"Fear","xref":"x","y":"Sadness","yref":"y"},{"font":{"color":"#000000"},"showarrow":false,"text":"77","x":"Happy","xref":"x","y":"Sadness","yref":"y"},{"font":{"color":"#000000"},"showarrow":false,"text":"246","x":"Neutral","xref":"x","y":"Sadness","yref":"y"},{"font":{"color":"#000000"},"showarrow":false,"text":"673","x":"Sadness","xref":"x","y":"Sadness","yref":"y"},{"font":{"color":"#000000"},"showarrow":false,"text":"15","x":"Surprise","xref":"x","y":"Sadness","yref":"y"},{"font":{"color":"#000000"},"showarrow":false,"text":"66","x":"Anger","xref":"x","y":"Neutral","yref":"y"},{"font":{"color":"#000000"},"showarrow":false,"text":"2","x":"Disgust","xref":"x","y":"Neutral","yref":"y"},{"font":{"color":"#000000"},"showarrow":false,"text":"66","x":"Fear","xref":"x","y":"Neutral","yref":"y"},{"font":{"color":"#000000"},"showarrow":false,"text":"85","x":"Happy","xref":"x","y":"Neutral","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"751","x":"Neutral","xref":"x","y":"Neutral","yref":"y"},{"font":{"color":"#000000"},"showarrow":false,"text":"249","x":"Sadness","xref":"x","y":"Neutral","yref":"y"},{"font":{"color":"#000000"},"showarrow":false,"text":"14","x":"Surprise","xref":"x","y":"Neutral","yref":"y"},{"font":{"color":"#000000"},"showarrow":false,"text":"50","x":"Anger","xref":"x","y":"Happy","yref":"y"},{"font":{"color":"#000000"},"showarrow":false,"text":"0","x":"Disgust","xref":"x","y":"Happy","yref":"y"},{"font":{"color":"#000000"},"showarrow":false,"text":"44","x":"Fear","xref":"x","y":"Happy","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"1471","x":"Happy","xref":"x","y":"Happy","yref":"y"},{"font":{"color":"#000000"},"showarrow":false,"text":"132","x":"Neutral","xref":"x","y":"Happy","yref":" ...
